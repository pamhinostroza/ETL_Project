# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
living_cost = "Resources/cost_living_index.csv"
living_cost_df = pd.read_csv(living_cost)
living_cost_df.head()
# Out:
#          State  costIndex  groceryCost  housingCost  utilitiesCost  \
# 0  Mississippi       86.1         91.6         70.1           89.1
# 1     Arkansas       86.9         92.0         73.9           91.8
# 2     Oklahoma       87.0         95.4         71.9           94.1
# 3     Missouri       87.1         96.6         70.6           99.6
# 4   New Mexico       87.5        100.9         77.7           87.9
#
#    transportationCost  miscCost
# 0                89.2      91.4
# 1                83.6      85.6
# 2                89.5      93.2
# 3                87.3      95.7
# 4                91.6     100.1

# %%
homes = "Resources/median_home_prices.csv"
homes_df = pd.read_csv(homes)
homes_df.head()
# Out:
#            State  MedianValue
# 0    Mississippi       119000
# 1  West Virginia       119600
# 2       Arkansas       127800
# 3       Oklahoma       136800
# 4       Kentucky       141000

# %%
income = "Resources/median_household_income2.csv"
income_df = pd.read_csv(income)
income_df.head()
# Out:
#    ID Race   Race   ID State       State  ID Year  Year  \
# 0        0  Total  04000US01     Alabama     2018  2018
# 1        0  Total  04000US02      Alaska     2018  2018
# 2        0  Total  04000US04     Arizona     2018  2018
# 3        0  Total  04000US05    Arkansas     2018  2018
# 4        0  Total  04000US06  California     2018  2018
#
#    Household Income by Race  Household Income by Race Moe  Slug State
# 0                     49861                         783.0     alabama
# 1                     74346                        2288.0      alaska
# 2                     59246                         732.0     arizona
# 3                     47062                         713.0    arkansas
# 4                     75277                         317.0  california

# %%
living_cost_df= living_cost_df.drop(columns=['groceryCost','housingCost','utilitiesCost','transportationCost','miscCost'])
living_cost_df.head()
# Out:
#          State  costIndex
# 0  Mississippi       86.1
# 1     Arkansas       86.9
# 2     Oklahoma       87.0
# 3     Missouri       87.1
# 4   New Mexico       87.5

# %%
income_df= income_df.drop(columns=['ID Race','ID State','ID Year','Household Income by Race Moe','Slug State'])
income_df.head()
# Out:
#     Race       State  Year  Household Income by Race
# 0  Total     Alabama  2018                     49861
# 1  Total      Alaska  2018                     74346
# 2  Total     Arizona  2018                     59246
# 3  Total    Arkansas  2018                     47062
# 4  Total  California  2018                     75277

# %%
income_df = income_df.loc[income_df['Year'] >= 2018]
income_df.head()
# Out:
#     Race       State  Year  Household Income by Race
# 0  Total     Alabama  2018                     49861
# 1  Total      Alaska  2018                     74346
# 2  Total     Arizona  2018                     59246
# 3  Total    Arkansas  2018                     47062
# 4  Total  California  2018                     75277

# %%
income_df = income_df.loc[income_df['State'] = str('Puerto Rico')]
income_df.head()
# Out:
#   File "<ipython-input-12-3bd79bf6ee8f>", line 1
#     income_df = income_df.loc[income_df['State'] = str('Puerto Rico')]
#                                                  ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('District of Columbia', 'Maryland')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-1ca1f5238903> in <module>
# ----> 1 average_income = income_df["District of Columbia", 'Maryland'].mean()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('District of Columbia', 'Maryland')
